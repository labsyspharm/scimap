# %% [markdown]
# # Getting started with SCIMAP

# %%
# import scimap
import scimap as sm

# %% [markdown]
# The sample data provided is generated by the mcmicro pipeline. Let's begin by exploring how to seamlessly import mcmicro pipeline output into Scimap with a straightforward single-line command.
#
# In this section of the tutorial, we'll be working with the single-cell data you've obtained, located within the directory "scimapExampleData/quantification". This dataset is rich with information, encompassing not just the expressions of various markers in individual cells but also valuable metadata such as XY coordinates and cell sizes.

# %%
# Provide the path to the single-cell feature table. Note that you can specify multiple paths as a list.
feature_table_path = ["/Users/aj/Dropbox (Partners HealthCare)/nirmal lab/resources/exemplarData/scimapExampleData/quantification/exemplar-001--unmicst_cell.csv"]

# create the annData object
adata = sm.pp.mcmicro_to_scimap(feature_table_path)
# Out:
# Loading exemplar-001--unmicst_cell.csv

# %% [markdown]
# ## Exploring contents of the annData object

# %%
adata

# The dataset contains 11201 cells and 9 markers
# The obs sections contains the meta data related to each cell
# Out:
# AnnData object with n_obs × n_vars = 11201 × 9
#     obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'CellID', 'imageid'
#     uns: 'all_markers'

# %%
# print the contents of the expression matrix. 
# By default on import, scimap applies a log transformation, you could set `log=False` if it is already log transformed
adata.X
# Out:
# array([[7.0737187 , 5.09012558, 6.56401223, ..., 6.56296306, 5.32982432,
#         6.75017136],
#        [7.02618545, 5.1830041 , 6.67364145, ..., 6.93618427, 5.96229317,
#         6.80626408],
#        [7.13129875, 5.06030083, 6.67480083, ..., 7.19693192, 5.66577023,
#         6.8434742 ],
#        ...,
#        [7.07756235, 5.31643791, 6.67671156, ..., 6.89449634, 5.64170442,
#         6.80208784],
#        [6.90256944, 5.31600484, 6.31401645, ..., 6.7339149 , 5.45318208,
#         6.77120455],
#        [7.06054074, 5.45066285, 6.32567977, ..., 6.34348493, 5.14151735,
#         6.73978032]])

# %%
# print metadata
adata.obs
# Out:
#                                    X_centroid   Y_centroid  Area  \
# exemplar-001--unmicst_cell_1      1767.692308   257.290598   117
# exemplar-001--unmicst_cell_2      1107.173913   665.869565    92
# exemplar-001--unmicst_cell_3      1116.413793   671.068966    58
# exemplar-001--unmicst_cell_4       982.728625   677.029740   269
# exemplar-001--unmicst_cell_5      1141.071078   680.125000   408
# ...                                       ...          ...   ...
# exemplar-001--unmicst_cell_11197  1270.593750  3131.731250   160
# exemplar-001--unmicst_cell_11198  1177.349057  3130.839623   106
# exemplar-001--unmicst_cell_11199  1255.904762  3131.285714   105
# exemplar-001--unmicst_cell_11200  1354.448276  3131.810345    58
# exemplar-001--unmicst_cell_11201  1125.662500  3133.100000    80
#
#                                   MajorAxisLength  MinorAxisLength  \
# exemplar-001--unmicst_cell_1            12.402944        12.006487
# exemplar-001--unmicst_cell_2            11.874070         9.982065
# exemplar-001--unmicst_cell_3            10.113305         7.629922
# exemplar-001--unmicst_cell_4            25.433196        15.183300
# exemplar-001--unmicst_cell_5            26.604670        19.759781
# ...                                           ...              ...
# exemplar-001--unmicst_cell_11197        19.414487        11.039993
# exemplar-001--unmicst_cell_11198        14.080819        10.062622
# exemplar-001--unmicst_cell_11199        15.623503         9.143181
# exemplar-001--unmicst_cell_11200         9.779089         7.836216
# exemplar-001--unmicst_cell_11201        14.311249         7.225347
#
#                                   Eccentricity  Solidity    Extent  \
# exemplar-001--unmicst_cell_1          0.250814  0.959016  0.812500
# exemplar-001--unmicst_cell_2          0.541562  0.948454  0.696970
# exemplar-001--unmicst_cell_3          0.656364  0.878788  0.585859
# exemplar-001--unmicst_cell_4          0.802251  0.835404  0.531621
# exemplar-001--unmicst_cell_5          0.669604  0.937931  0.739130
# ...                                        ...       ...       ...
# exemplar-001--unmicst_cell_11197      0.822582  0.893855  0.701754
# exemplar-001--unmicst_cell_11198      0.699499  0.876033  0.706667
# exemplar-001--unmicst_cell_11199      0.810875  0.882353  0.596591
# exemplar-001--unmicst_cell_11200      0.598231  0.878788  0.725000
# exemplar-001--unmicst_cell_11201      0.863194  0.941176  0.714286
#
#                                   Orientation  CellID  \
# exemplar-001--unmicst_cell_1        -1.146733       1
# exemplar-001--unmicst_cell_2        -0.435290       2
# exemplar-001--unmicst_cell_3         1.221658       3
# exemplar-001--unmicst_cell_4        -0.705293       4
# exemplar-001--unmicst_cell_5        -0.711002       5
# ...                                       ...     ...
# exemplar-001--unmicst_cell_11197    -1.364872   11197
# exemplar-001--unmicst_cell_11198     1.478579   11198
# exemplar-001--unmicst_cell_11199    -1.065479   11199
# exemplar-001--unmicst_cell_11200    -1.072712   11200
# exemplar-001--unmicst_cell_11201     1.370610   11201
#
#                                                      imageid
# exemplar-001--unmicst_cell_1      exemplar-001--unmicst_cell
# exemplar-001--unmicst_cell_2      exemplar-001--unmicst_cell
# exemplar-001--unmicst_cell_3      exemplar-001--unmicst_cell
# exemplar-001--unmicst_cell_4      exemplar-001--unmicst_cell
# exemplar-001--unmicst_cell_5      exemplar-001--unmicst_cell
# ...                                                      ...
# exemplar-001--unmicst_cell_11197  exemplar-001--unmicst_cell
# exemplar-001--unmicst_cell_11198  exemplar-001--unmicst_cell
# exemplar-001--unmicst_cell_11199  exemplar-001--unmicst_cell
# exemplar-001--unmicst_cell_11200  exemplar-001--unmicst_cell
# exemplar-001--unmicst_cell_11201  exemplar-001--unmicst_cell
#
# [11201 rows x 11 columns]

# %%
# lastly lets print the markers
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [ELANE, CD57, CD45, CD11B, SMA, CD16, ECAD, FOXP3, NCAM]

# %% [markdown]
# Upon inspection, you will note the following characteristics about the data: it has undergone log transformation, is devoid of DNA channels, and lacks background channels. By default, the data has been processed to address key considerations: it has been log-transformed, DNA channels have been removed, and background channels have been excluded. However, these preprocessing steps can be customized or overridden as needed.

# %% [markdown]
# <hr>

# %% [markdown]
# ## What if your data was not generated using the MCMICRO pipeline?

# %%
# import packages
import anndata as ad
import pandas as pd

# %% [markdown]
# After importing the necessary packages, you can create an AnnData object as shown below.

# %% [markdown]
# ```
# # Load data
# data = pd.read_csv ('path/to/counts_table.csv') # Counts matrix
# meta = pd.read_csv ('path/to/meta_data.csv') # Meta data like x and y coordinates
#
# # combine the data and metadata file to generate the AnnData object
# adata = ad.AnnData (data)
# adata.obs = meta
#
# ```

# %% [markdown]
# <hr>

# %% [markdown]
# ## Save the annData object

# %% [markdown]
# Once the AnnData object is created, it becomes the central data structure for all subsequent analyses. This is highly beneficial because it encapsulates all results within the object, eliminating the need to manage multiple related files. You can conveniently share this single file with collaborators, allowing them to continue the analysis seamlessly or resume from where you left off. Furthermore, numerous single-cell analysis tools, such as Scanpy, are built upon this framework. This integration allows for the straightforward application of functions from various packages without the necessity of data reformatting to suit each tool's specific requirements.

# %%
# Save the results
adata.write('/Users/aj/Dropbox (Partners HealthCare)/nirmal lab/resources/exemplarData/scimapExampleData/scimapExampleData.h5ad')

# %% [markdown]
# `sm.tl.cluster` function can be used for clustering cells within the dataset. It supports three popular clustering algorithms:
#
# - kmeans
# - phenograph
# - leiden
#
# Users are encouraged to select the clustering algorithm that best matches their data's nature and their analytical goals.

# %%
adata = sm.tl.cluster(adata, method='leiden', resolution=0.2)
# Out:
# Leiden clustering
# /Users/aj/miniconda3/envs/scimap/lib/python3.10/site-packages/scanpy/preprocessing/_pca.py:229: ImplicitModificationWarning:
#
# Setting element `.obsm['X_pca']` of view, initializing view as actual.

# %%
# view the results
adata.obs['leiden'].value_counts()
# Out:
# leiden
# 0    4070
# 1    2847
# 2    2658
# 3    1063
# 4     482
# 5      81
# Name: count, dtype: int64
